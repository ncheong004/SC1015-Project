# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
graduate_employment_survey=pd.read_csv("1015 Project/graduate-employment-survey.csv",engine='python')

# %%
graduate_employment_survey.head()
# Out:
#    year                        university  \
# 0  2013  Nanyang Technological University
# 1  2013  Nanyang Technological University
# 2  2013  Nanyang Technological University
# 3  2013  Nanyang Technological University
# 4  2013  Nanyang Technological University
#
#                                           school  \
# 0  College of Business (Nanyang Business School)
# 1  College of Business (Nanyang Business School)
# 2  College of Business (Nanyang Business School)
# 3  College of Business (Nanyang Business School)
# 4                         College of Engineering
#
#                                         degree employment_rate_overall  \
# 0                     Accountancy and Business                    97.4
# 1  Accountancy (3-yr direct Honours Programme)                    97.1
# 2     Business (3-yr direct Honours Programme)                    90.9
# 3                       Business and Computing                    87.5
# 4                        Aerospace Engineering                    95.3
#
#   employment_rate_ft_perm basic_monthly_mean basic_monthly_median  \
# 0                    96.1               3701                 3200
# 1                    95.7               2850                 2700
# 2                    85.7               3053                 3000
# 3                    87.5               3557                 3400
# 4                    95.3               3494                 3500
#
#   gross_monthly_mean gross_monthly_median gross_mthly_25_percentile  \
# 0               3727                 3350                      2900
# 1               2938                 2700                      2700
# 2               3214                 3000                      2700
# 3               3615                 3400                      3000
# 4               3536                 3500                      3100
#
#   gross_mthly_75_percentile
# 0                      4000
# 1                      2900
# 2                      3500
# 3                      4100
# 4                      3816

# %%
graduate_employment_survey=graduate_employment_survey[graduate_employment_survey['year']==2019]

# %%
graduate_employment_survey[80:]
# Out:
#      year                                     university  \
# 787  2019               National University of Singapore
# 788  2019               National University of Singapore
# 789  2019               National University of Singapore
# 790  2019               National University of Singapore
# 791  2019              Singapore Institute of Technology
# 792  2019              Singapore Institute of Technology
# 793  2019              Singapore Institute of Technology
# 794  2019              Singapore Institute of Technology
# 795  2019              Singapore Institute of Technology
# 796  2019              Singapore Institute of Technology
# 797  2019              Singapore Institute of Technology
# 798  2019              Singapore Institute of Technology
# 799  2019              Singapore Institute of Technology
# 800  2019              Singapore Institute of Technology
# 801  2019              Singapore Institute of Technology
# 802  2019              Singapore Institute of Technology
# 803  2019              Singapore Institute of Technology
# 804  2019              Singapore Institute of Technology
# 805  2019              Singapore Institute of Technology
# 806  2019              Singapore Institute of Technology
# 807  2019              Singapore Institute of Technology
# 808  2019              Singapore Institute of Technology
# 809  2019              Singapore Institute of Technology
# 810  2019              Singapore Institute of Technology
# 811  2019              Singapore Institute of Technology
# 812  2019              Singapore Institute of Technology
# 813  2019              Singapore Institute of Technology
# 814  2019              Singapore Institute of Technology
# 815  2019              Singapore Institute of Technology
# 816  2019              Singapore Institute of Technology
# 817  2019              Singapore Institute of Technology
# 818  2019              Singapore Institute of Technology
# 819  2019              Singapore Institute of Technology
# 820  2019              Singapore Institute of Technology
# 821  2019              Singapore Institute of Technology
# 822  2019              Singapore Institute of Technology
# 823  2019              Singapore Institute of Technology
# 824  2019              Singapore Institute of Technology
# 825  2019              Singapore Institute of Technology
# 826  2019              Singapore Institute of Technology
# 827  2019                Singapore Management University
# 828  2019                Singapore Management University
# 829  2019                Singapore Management University
# 830  2019                Singapore Management University
# 831  2019                Singapore Management University
# 832  2019                Singapore Management University
# 833  2019                Singapore Management University
# 834  2019                Singapore Management University
# 835  2019                Singapore Management University
# 836  2019                Singapore Management University
# 837  2019                Singapore Management University
# 838  2019                Singapore Management University
# 839  2019        Singapore University of Social Sciences
# 840  2019        Singapore University of Social Sciences
# 841  2019        Singapore University of Social Sciences
# 842  2019        Singapore University of Social Sciences
# 843  2019  Singapore University of Technology and Design
# 844  2019  Singapore University of Technology and Design
# 845  2019  Singapore University of Technology and Design
# 846  2019  Singapore University of Technology and Design
#
#                                                 school  \
# 787                                   Yale-NUS College
# 788                                   Yale-NUS College
# 789                      Multi-Disciplinary Programmes
# 790                      Multi-Disciplinary Programmes
# 791                    DigiPen Institute of Technology
# 792                    DigiPen Institute of Technology
# 793                    DigiPen Institute of Technology
# 794                    DigiPen Institute of Technology
# 795            Singapore Institute of Technology (SIT)
# 796            Singapore Institute of Technology (SIT)
# 797            Singapore Institute of Technology (SIT)
# 798            Singapore Institute of Technology (SIT)
# 799            Singapore Institute of Technology (SIT)
# 800            Singapore Institute of Technology (SIT)
# 801            Singapore Institute of Technology (SIT)
# 802            Singapore Institute of Technology (SIT)
# 803                SIT-DigiPen Institute of Technology
# 804                              SIT-Massey University
# 805                           SIT-Newcastle University
# 806                           SIT-Newcastle University
# 807                           SIT-Newcastle University
# 808                           SIT-Newcastle University
# 809                           SIT-Newcastle University
# 810                           SIT-Newcastle University
# 811  SIT-Trinity College Dublin / Trinity College D...
# 812  SIT-Trinity College Dublin / Trinity College D...
# 813  SIT-Trinity College Dublin / Trinity College D...
# 814  SIT-Trinity College Dublin / Trinity College D...
# 815                          SIT-University of Glasgow
# 816                     Technische Universität München
# 817                     Technische Universität München
# 818                  The Culinary Institute of America
# 819                          The Glasgow School of Art
# 820                          The Glasgow School of Art
# 821                              University of Glasgow
# 822                              University of Glasgow
# 823                              University of Glasgow
# 824                              University of Glasgow
# 825                              University of Glasgow
# 826                            University of Liverpool
# 827         School of Accountancy (4-year programme) *
# 828         School of Accountancy (4-year programme) *
# 829            School of Business (4-year programme) *
# 830            School of Business (4-year programme) *
# 831           School of Economics (4-year programme) *
# 832           School of Economics (4-year programme) *
# 833  School of Information Systems (4-year programm...
# 834  School of Information Systems (4-year programm...
# 835     School of Social Sciences (4-year programme) *
# 836     School of Social Sciences (4-year programme) *
# 837                 School of Law (4-year programme) *
# 838                 School of Law (4-year programme) *
# 839             S R Nathan School of Human Development
# 840                                 School of Business
# 841                                 School of Business
# 842                                 School of Business
# 843                                                 na
# 844                                                 na
# 845                                                 na
# 846                                                 na
#
#                                                 degree  \
# 787                      Bachelor of Arts with Honours
# 788                 Bachelor of Science with Honours ^
# 789     Bachelor of Engineering (Computer Engineering)
# 790                  Bachelor of Environmental Studies
# 791                  Bachelor of Arts in Game Design ^
# 792  Bachelor of Fine Arts in Digital Art and Anima...
# 793  Bachelor of Science in Computer Science and Ga...
# 794  Bachelor of Science in Computer Science in Rea...
# 795               Bachelor of Accountancy with Honours
# 796  Bachelor of Engineering with Honours in Inform...
# 797  Bachelor of Engineering with Honours in Inform...
# 798  Bachelor of Engineering with Honours in Pharma...
# 799  Bachelor of Engineering with Honours in Sustai...
# 800  Bachelor of Engineering with Honours in Sustai...
# 801  Bachelor of Engineering with Honours in Telema...
# 802      Bachelor of Hospitality Business with Honours
# 803  Bachelor of Engineering in Systems Engineering...
# 804           Bachelor of Food Technology with Honours
# 805  Bachelor of Engineering with Honours in Chemic...
# 806  Bachelor of Engineering with Honours in Electr...
# 807  Bachelor of Engineering with Honours in Marine...
# 808  Bachelor of Engineering with Honours in Mechan...
# 809  Bachelor of Engineering with Honours in Naval ...
# 810  Bachelor of Engineering with Honours in Offsho...
# 811    Bachelor in Science (Diagnostic Radiography) **
# 812         Bachelor in Science (Occupational Therapy)
# 813                Bachelor in Science (Physiotherapy)
# 814         Bachelor in Science (Radiation Therapy) **
# 815        Bachelor of Science with Honours in Nursing
# 816        Bachelor of Science in Chemical Engineering
# 817  Bachelor of Science in Electrical Engineering ...
# 818  Bachelor of Business Administration in Food Bu...
# 819  Bachelor of Arts with Honours in Communication...
# 820   Bachelor of Arts with Honours in Interior Design
# 821  Bachelor of Engineering with Honours in Aerona...
# 822  Bachelor of Engineering with Honours in Aerosp...
# 823  Bachelor of Engineering with Honours in Mechan...
# 824  Bachelor of Engineering with Honours in Mechat...
# 825  Bachelor of Science with Honours in Computing ...
# 826  Bachelor of Arts with Honours in Criminology a...
# 827                                        Accountancy
# 828                  Accountancy (Cum Laude and above)
# 829                                Business Management
# 830          Business Management (Cum Laude and above)
# 831                                          Economics
# 832                    Economics (Cum Laude and above)
# 833                                Information Systems
# 834          Information Systems (Cum Laude and above)
# 835                                    Social Sciences
# 836              Social Sciences (Cum Laude and above)
# 837                                              Law #
# 838                        Law (Cum Laude and above) #
# 839              Bachelor of Human Resource Management
# 840                            Bachelor of Accountancy
# 841                     Bachelor of Science in Finance
# 842                   Bachelor of Science in Marketing
# 843  Bachelor of Engineering (Engineering Product D...
# 844  Bachelor of Engineering (Information Systems T...
# 845  Bachelor of Engineering (Engineering Systems a...
# 846  Bachelor of Science (Architecture and Sustaina...
#
#     employment_rate_overall employment_rate_ft_perm basic_monthly_mean  \
# 787                      96                      77               4066
# 788                    94.7                    89.5               6962
# 789                    92.9                    91.7               4653
# 790                    88.4                    67.4               3329
# 791                    83.3                    79.2               3122
# 792                    81.3                      50               3036
# 793                    91.3                      87               3760
# 794                     100                    94.9               4447
# 795                    93.7                    89.2               3181
# 796                    97.5                      95               4171
# 797                     100                    97.4               4090
# 798                    92.2                    90.6               3237
# 799                    92.5                    92.5               3433
# 800                    93.8                    90.6               3856
# 801                     100                      97               3777
# 802                    89.1                    74.6               2972
# 803                    95.2                    90.5               3931
# 804                      93                    88.4               2962
# 805                    82.2                    73.3               3217
# 806                    91.3                    82.6               3489
# 807                     100                     100               3318
# 808                      80                    66.7               3227
# 809                      na                      na                 na
# 810                      na                      na                 na
# 811                      na                      na                 na
# 812                     100                     100               3429
# 813                    98.3                    98.3               3479
# 814                      na                      na                 na
# 815                     100                    95.8               3522
# 816                    81.8                    77.3               3213
# 817                      na                      na                 na
# 818                      81                    61.9               2532
# 819                    78.7                    55.3               2724
# 820                    87.1                    80.6               2692
# 821                    77.1                    64.6               3500
# 822                    82.4                    67.6               3863
# 823                      97                    93.9               3569
# 824                    93.2                    83.1               3764
# 825                    92.3                    89.2               4294
# 826                    80.2                    70.4               3647
# 827                    96.4                    93.7               3753
# 828                    97.9                    97.9               4364
# 829                      91                    84.8               4056
# 830                      93                    90.4               4504
# 831                    87.1                    81.3               4042
# 832                    94.2                    89.9               4401
# 833                    95.1                    90.2               4413
# 834                      98                      96               5029
# 835                    92.2                    82.8               3523
# 836                    92.7                    90.2               3599
# 837                    99.1                    98.2               4942
# 838                    98.6                    97.1               5136
# 839                    87.1                    74.2               2942
# 840                    91.1                    83.3               2880
# 841                    88.6                    88.6               3708
# 842                    88.3                      70               2993
# 843                    84.2                    80.2               3991
# 844                    88.8                    85.7               4599
# 845                    89.9                    87.3               3944
# 846                     100                    91.8               3923
#
#     basic_monthly_median gross_monthly_mean gross_monthly_median  \
# 787                 3600               4197                 3684
# 788                 5000               7139                 5000
# 789                 4000               4732                 4000
# 790                 3300               3332                 3325
# 791                 3120               3167                 3220
# 792                 3150               3051                 3150
# 793                 3800               3791                 3800
# 794                 4400               4474                 4400
# 795                 3100               3239                 3100
# 796                 4000               4319                 4100
# 797                 4034               4188                 4190
# 798                 3162               3748                 3660
# 799                 3360               3484                 3500
# 800                 3800               3976                 3842
# 801                 3750               3811                 3750
# 802                 2800               3102                 3000
# 803                 3921               4024                 3975
# 804                 2975               2978                 2975
# 805                 3200               3463                 3500
# 806                 3400               3542                 3500
# 807                 3300               3393                 3300
# 808                 3100               3269                 3100
# 809                   na                 na                   na
# 810                   na                 na                   na
# 811                   na                 na                   na
# 812                 3400               3466                 3425
# 813                 3400               3498                 3400
# 814                   na                 na                   na
# 815                 3500               3772                 3800
# 816                 3100               3471                 3300
# 817                   na                 na                   na
# 818                 2350               2852                 2625
# 819                 2800               2832                 2800
# 820                 2700               2760                 2700
# 821                 3500               3597                 3500
# 822                 3550               3993                 3700
# 823                 3500               3722                 3500
# 824                 3600               3793                 3600
# 825                 4000               4366                 4200
# 826                 3526               3823                 3695
# 827                 3000               3802                 3050
# 828                 3500               4431                 3600
# 829                 3600               4181                 3750
# 830                 4000               4614                 4167
# 831                 3800               4159                 3900
# 832                 4000               4520                 4038
# 833                 4166               4549                 4300
# 834                 5000               5212                 5000
# 835                 3400               3629                 3500
# 836                 3500               3742                 3500
# 837                 4600               5064                 4900
# 838                 5000               5324                 5550
# 839                 3000               2975                 3000
# 840                 3000               2900                 3000
# 841                 3400               3722                 3450
# 842                 3000               3169                 3000
# 843                 3900               4042                 4000
# 844                 4400               4636                 4400
# 845                 3800               4082                 4000
# 846                 3897               3985                 3900
#
#     gross_mthly_25_percentile gross_mthly_75_percentile
# 787                      3400                      4567
# 788                      4150                      9967
# 789                      3750                      4900
# 790                      3000                      3600
# 791                      3000                      3500
# 792                      2750                      3275
# 793                      3550                      4000
# 794                      4000                      5200
# 795                      3000                      3250
# 796                      3900                      5000
# 797                      3600                      4550
# 798                      3500                      4044
# 799                      3200                      3700
# 800                      3700                      4210
# 801                      3500                      4000
# 802                      2800                      3270
# 803                      3500                      4470
# 804                      2750                      3250
# 805                      3200                      3600
# 806                      3250                      3600
# 807                      3200                      3521
# 808                      3050                      3500
# 809                        na                        na
# 810                        na                        na
# 811                        na                        na
# 812                      3308                      3650
# 813                      3400                      3620
# 814                        na                        na
# 815                      3450                      4085
# 816                      3110                      3600
# 817                        na                        na
# 818                      2200                      3350
# 819                      2450                      3000
# 820                      2400                      3000
# 821                      3200                      4000
# 822                      3400                      4600
# 823                      3300                      3800
# 824                      3300                      4000
# 825                      3700                      5100
# 826                      3400                      4050
# 827                      3000                      4000
# 828                      3000                      5000
# 829                      3300                      4600
# 830                      3600                      5120
# 831                      3500                      4500
# 832                      3600                      4600
# 833                      4000                      5000
# 834                      4300                      5550
# 835                      3065                      4000
# 836                      3100                      4070
# 837                      4200                      5800
# 838                      4500                      6000
# 839                      2800                      3300
# 840                      2750                      3000
# 841                      3085                      3750
# 842                      2800                      3400
# 843                      3660                      4500
# 844                      3800                      5000
# 845                      3500                      4400
# 846                      3600                      4100

# %%
no_data_list=pd.DataFrame(graduate_employment_survey.loc[graduate_employment_survey['gross_monthly_median']=='na'])

# %%
no_data_list.index
# Out:
# Int64Index([712, 714, 716, 718, 723, 727, 729, 768, 775, 776, 809, 810, 811,
#             814, 817],
#            dtype='int64')

# %%
list2=[]
for i in range(len(graduate_employment_survey)):
    if 'Cum Laude and above' in graduate_employment_survey['degree'].iloc[i]:
        list2.append(i)

# %%
cum_laude_list=pd.DataFrame(graduate_employment_survey.iloc[list2])

# %%
cum_laude_list.index
# Out:
# Int64Index([828, 830, 832, 834, 836, 838], dtype='int64')

# %%
list2=cum_laude_list.index

# %%
list3=[]
for i in range(len(graduate_employment_survey)):
    if 'Hons' in graduate_employment_survey['degree'].iloc[i]:
        list3.append(i)

hons_list=pd.DataFrame(graduate_employment_survey.iloc[list3])
list3=hons_list.index

# %%
list4=[]
for i in range(len(graduate_employment_survey)):
    if 'Honours' in graduate_employment_survey['degree'].iloc[i]:
        list4.append(i)

hons_list_sit=pd.DataFrame(graduate_employment_survey.iloc[list4])
list4=hons_list_sit.index

# %%
list4
# Out:
# Int64Index([787, 788, 795, 796, 797, 798, 799, 800, 801, 802, 804, 805, 806,
#             807, 808, 809, 810, 815, 819, 820, 821, 822, 823, 824, 825, 826],
#            dtype='int64')

# %%
list1=[]
for i in no_data_list.index:
    list1.append(i)
for i in cum_laude_list.index:
    if i not in list1:
        list1.append(i)
for i in hons_list.index:
    if i not in list1:
        list1.append(i)
for i in hons_list_sit.index:
    if i not in list1:
        list1.append(i)

# %%
graduate_employment_survey=graduate_employment_survey.drop(no_data_list.index)
graduate_employment_survey=graduate_employment_survey.drop(cum_laude_list.index)
graduate_employment_survey=graduate_employment_survey.drop(hons_list.index)
list4=[]
for i in range(len(graduate_employment_survey)):
    if 'Honours' in graduate_employment_survey['degree'].iloc[i]:
        list4.append(i)

hons_list_sit=pd.DataFrame(graduate_employment_survey.iloc[list4])
graduate_employment_survey=graduate_employment_survey.drop(hons_list_sit.index)

# %%
graduate_employment_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 707 to 846
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       90 non-null     int64
#  1   university                 90 non-null     object
#  2   school                     90 non-null     object
#  3   degree                     90 non-null     object
#  4   employment_rate_overall    90 non-null     object
#  5   employment_rate_ft_perm    90 non-null     object
#  6   basic_monthly_mean         90 non-null     object
#  7   basic_monthly_median       90 non-null     object
#  8   gross_monthly_mean         90 non-null     object
#  9   gross_monthly_median       90 non-null     object
#  10  gross_mthly_25_percentile  90 non-null     object
#  11  gross_mthly_75_percentile  90 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 9.1+ KB

# %%
graduate_employment_survey['employment_rate_overall']=pd.to_numeric(graduate_employment_survey['employment_rate_overall'])

# %%
graduate_employment_survey['employment_rate_ft_perm']=pd.to_numeric(graduate_employment_survey['employment_rate_ft_perm'])

# %%
graduate_employment_survey['basic_monthly_mean']=pd.to_numeric(graduate_employment_survey['basic_monthly_mean'])

# %%
graduate_employment_survey['basic_monthly_median']=pd.to_numeric(graduate_employment_survey['basic_monthly_median'])

# %%
graduate_employment_survey['gross_monthly_mean']=pd.to_numeric(graduate_employment_survey['gross_monthly_mean'])

# %%
graduate_employment_survey['gross_monthly_median']=pd.to_numeric(graduate_employment_survey['gross_monthly_median'])

# %%
graduate_employment_survey['gross_mthly_25_percentile']=pd.to_numeric(graduate_employment_survey['gross_mthly_25_percentile'])

# %%
graduate_employment_survey['gross_mthly_75_percentile']=pd.to_numeric(graduate_employment_survey['gross_mthly_75_percentile'])

# %%
stream_ges=['B','B','B','S','S','S','S','S','S','S','S','S','S','S','S','S','A','A','A','A','A','A','A',
            'A','A','A','A','S','S','S','S','S','S','S','S','A','S','S','A','A','S','S','S','S','S','S',
           'S','S','S','S','A','S','S','B','B','S','S','S','A','A','S','S','S','S','A','S','S','A','A','S',
           'S','S','S','S','S','B','B','B','A','S','A','A','A','B','S','S','S','S','S','S',]
print(len(stream_ges))
rank_points_ges=[72.5,82.5,73.75,83.75,78.75,75,75,63.75,75,83.75,66.25,68.75,72.5,68.75,70,67.5,71.25,71.25,81.25,77.5,
                71.25,68.75,71.25,70,78.75,80,75,81.25,82.5,76.25,83.75,72.5,82.5,65,68.75,73.75,78.75,85,80,78.75,85,72.5,
                73.75,67.5,71.25,71.25,70,71.25,70,72.5,85,82.5,85,77.5,78.75,85,83.75,85,67.5,71.25,68.75,71.25,87.5,67.5,75,82.5,
                 81.25,75,75,75,75,75,75,75,75,75,72.5,76.25,72.5,75,76.25,83.75,75,75,75,75,78.75,78.75,78.75,78.75]

#SIT=75
#SUSS=75
#SUTD=78.75
graduate_employment_survey['Stream']=stream_ges
graduate_employment_survey['Rank Points']=rank_points_ges
# Out:
# 90

# %%
graduate_employment_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 707 to 846
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       90 non-null     int64
#  1   university                 90 non-null     object
#  2   school                     90 non-null     object
#  3   degree                     90 non-null     object
#  4   employment_rate_overall    90 non-null     float64
#  5   employment_rate_ft_perm    90 non-null     float64
#  6   basic_monthly_mean         90 non-null     int64
#  7   basic_monthly_median       90 non-null     int64
#  8   gross_monthly_mean         90 non-null     int64
#  9   gross_monthly_median       90 non-null     int64
#  10  gross_mthly_25_percentile  90 non-null     int64
#  11  gross_mthly_75_percentile  90 non-null     int64
#  12  Stream                     90 non-null     object
#  13  Rank Points                90 non-null     float64
# dtypes: float64(3), int64(7), object(4)
# memory usage: 10.5+ KB

# %%
sns.barplot(data=graduate_employment_survey.head(),x='employment_rate_overall',y='gross_monthly_mean')
# Out:
# <AxesSubplot:xlabel='employment_rate_overall', ylabel='gross_monthly_mean'>

# %%
ges_DegandUni=[]
degrees=[]
for i in range(len(graduate_employment_survey)):
    a=graduate_employment_survey.iloc[i][3]
    while(a[-1].isalpha()==False):
        a=a[:-1]
    if '(' in a and ')' not in a:
        a=a+')'
    degrees.append(a)
graduate_employment_survey['degree']=degrees
for i in range(len(graduate_employment_survey)):
    ges_DegandUni.append(graduate_employment_survey.iloc[i][3]+ ' at ' +graduate_employment_survey.iloc[i][1])
ges_modified=({"Degree and University":ges_DegandUni,"Degrees":degrees})

# %%
def user_passion_func():
    listofcourses=[]
    listofdeg=[]
    while(True):
        print()
        user_pas=input("Please enter your passion (Enter '.' to end): ")
        if (user_pas=='.'):
            False
            print()
            for i in (listofcourses):
                print(i)
            break
        else:
            user_pas=user_pas.capitalize()
            user_pas=user_pas[:5]
            if user_pas=='Biz':
                user_pas='Business'
            if user_pas=='Med':
                user_pas='Medicine'
            #listofdeg=graduate_employment_survey['degree'].unique()
            for i in range(len(ges_modified['Degree and University'])):
                if user_pas in ges_modified['Degree and University'][i]:
                    if ges_modified['Degree and University'][i] not in listofcourses:
                        listofcourses.append(ges_modified['Degree and University'][i])
                        listofdeg.append(i)
                        print(ges_modified['Degree and University'][i])
                    else:
                        index=listofcourses.index(ges_modified['Degree and University'][i])
                        while(index>0):
                            listofcourses[index]=listofcourses[index-1]
                            index-=1
                        listofcourses[0]=ges_modified['Degree and University'][i]
                        
    return listofdeg

# %%
degrees=graduate_employment_survey['degree'].unique()

# %%
len(degrees)
# Out:
# 88

# %%
degrees_sorted=[]
for i in degrees:
    i=graduate_employment_survey[graduate_employment_survey['degree']==i]
    degrees_sorted.append(i)

# %%
gross_monthly_median=[]
for i in range(len(degrees_sorted)):
    gross_monthly_median.append((degrees_sorted[i]['degree'].max(),degrees_sorted[i]['university'].max(),degrees_sorted[i]['gross_monthly_median'].max(),
                                 degrees_sorted[i]['gross_mthly_25_percentile'].max(),degrees_sorted[i]['gross_mthly_75_percentile'].max(),
                                degrees_sorted[i]['gross_monthly_mean'].max()))

# %%
for j in range(len(gross_monthly_median)-1):
    for i in range(len(gross_monthly_median)-1):
        if gross_monthly_median[i][2]<gross_monthly_median[i+1][2]:
            temp=gross_monthly_median[i]
            gross_monthly_median[i]=gross_monthly_median[i+1]
            gross_monthly_median[i+1]=temp

# %%
top_100_gross_monthly_median=gross_monthly_median[:100]

# %%
top_100_gross_monthly_median_degrees=[]
top_100_gross_monthly_median_university=[]
top_100_gross_monthly_median_degrees_salaries=[]
top_100_gross_monthly_median_degrees_salaries_25pct=[]
top_100_gross_monthly_median_degrees_salaries_75pct=[]
top_100_gross_monthly_mean=[]
for i in range(len(top_100_gross_monthly_median)):
    top_100_gross_monthly_median_degrees.append(top_100_gross_monthly_median[i][0])
    top_100_gross_monthly_median_university.append(top_100_gross_monthly_median[i][1])
    top_100_gross_monthly_median_degrees_salaries.append(top_100_gross_monthly_median[i][2])
    top_100_gross_monthly_median_degrees_salaries_25pct.append(top_100_gross_monthly_median[i][3])
    top_100_gross_monthly_median_degrees_salaries_75pct.append(top_100_gross_monthly_median[i][4])
    top_100_gross_monthly_mean.append(top_100_gross_monthly_median[i][5])
    while (top_100_gross_monthly_median_degrees[i][-1].isalpha()==False):
        top_100_gross_monthly_median_degrees[i]=top_100_gross_monthly_median_degrees[i][:-1]
    if ('(' in top_100_gross_monthly_median_degrees[i] and ')' not in top_100_gross_monthly_median_degrees[i]):
        top_100_gross_monthly_median_degrees[i]+=')'
    #top_100_gross_monthly_median_degrees[i]+=' at '+top_100_gross_monthly_median_university[i]

# %%
top_100_gross_monthly_median_df=pd.DataFrame(data={'degree':top_100_gross_monthly_median_degrees,
                                                  'University':top_100_gross_monthly_median_university,
                                                  'Gross Monthly Median':top_100_gross_monthly_median_degrees_salaries,
                                                  'GMM_25pct':top_100_gross_monthly_median_degrees_salaries_25pct,
                                                  'GMM_75pct':top_100_gross_monthly_median_degrees_salaries_75pct,
                                                  'Gross Monthly Mean':top_100_gross_monthly_mean})

# %%
p=sns.barplot(data=top_100_gross_monthly_median_df.head(20),x=top_100_gross_monthly_median_df[:20].index,y='Gross Monthly Median',
           hue='degree')
plt.legend(bbox_to_anchor=(1.04, 0.5), loc='center left', borderaxespad=0)

# %%
rank_point_list_10th_pct=[90,85,85,85,85,85,83.75,83.75,75,78.75,75,83.75,83.75,85,75,75,77.5,67.5,75,82.5,75,
                         72.5,71.25,71.25,70,77.5,82.5,78.75,78.75,75,73.75,72.5,78.75,80,75,78.75,75,73.75,78.75,75,75,71.25,85,75,
                         76.25,66.25,80,72.5,75,75,70,83.75,65,76.25,75,75,76.25,75,75,78.75,76.25,70,71.25,75,67.5,68.75,81.25,
                         75,81.25,73.75,75,75,71.25,81.25,71.25,76.25,68.75,75,82.5,72.5,71.25,71.25,82.5,78.75,75,75,75,75]

# need to enter more value here
#SIT=75 SUTD=78.75

# %%
top_100_gross_monthly_median_df['Rank Points']=rank_point_list_10th_pct

# %%
stream=['S','A','S','S','S','S','A','S','S','S','S','S','S','S','S','S','S','A','S','S','S','S','S','S',
        'S','S','S','S','S','S','S','A','S','A','S','S','S','A','S','S','S','S','S','S','A','S','S','S','S','A',
       'A','S','S','A','S','A','A','S','S','A','S','S','A','S','S','S','S','A','S','A','S','A','A','A','A','A','S',
       'A','S','S','A','A','S','S','A','S','S','S']

# %%
len(stream)
# Out:
# 88

# %%
top_100_gross_monthly_median_df['Stream']=stream

# %% [markdown]
# user_RP=float(input("Please enter your rank points: "))
# user_stream=input ("Please enter your preferred stream: ")
# courselist=[]
# max_Salary=0
# for i in range(len(top_100_gross_monthly_median_df)):
#     if (user_stream==top_100_gross_monthly_median_df.iloc[i]['Stream']
#        and user_RP>=top_100_gross_monthly_median_df.iloc[i]['Rank Points']):
#         if (top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']>max_Salary):
#             courselist=[]
#             courselist.append(top_100_gross_monthly_median_df.iloc[i]['degree'])
#             max_Salary=top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']
#         elif (top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']==max_Salary):
#             courselist.append(top_100_gross_monthly_median_df.iloc[i]['degree'])
# print("List of courses: ")
# print(courselist)
# print("")
# print("Your maximum salary is: ")
# print(max_Salary)

# %%
top_100_gmm_unique_rp_RP=[]
top_100_gmm_unique_rp_degree=[]
top_100_gmm_unique_rp_stream=[]
top_100_gmm_unique_rp_gmm=[]
top_100_gmm_unique_rp=[]
top_100_gmm_unique_rp_university=[]

# %%
top_100_gmm_unique_rp_streamandRP=[]

# %%
top_100_gross_monthly_median_df.iloc[10]['Rank Points']
# Out:
# 75.0

# %%
#top_50_gross_monthly_median_df=pd.DataFrame()
for i in range(len(top_100_gross_monthly_median_df)):
    if ((top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
         top_100_gross_monthly_median_df.iloc[i]['Stream']) in top_100_gmm_unique_rp_streamandRP):
        index=top_100_gmm_unique_rp_streamandRP.index((top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
                                           top_100_gross_monthly_median_df.iloc[i]['Stream']))
        if (top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']>top_100_gmm_unique_rp_gmm[index]):
            top_100_gmm_unique_rp_degree=(top_100_gross_monthly_median_df.iloc['degree'])
            top_100_gmm_unique_rp_gmm[index]=top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']
            top_100_gmm_unique_rp_streamandRP[index]=(top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
                                                     top_100_gross_monthly_median_df.iloc[i]['Stream'])
            top_100_gmm_unique_rp_university[index]=top_100_gross_monthly_median_df.iloc[i]['University']
            top_100_gmm_unique_rp[index]=(top_100_gross_monthly_median_df.iloc[i]['degree'],
                                         top_100_gross_monthly_median_df.iloc[i]['University'],
                                         top_100_gross_monthly_median_df.iloc[i]['Stream'],
                                         top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
                                         top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median'])
    else:
        top_100_gmm_unique_rp_degree.append(top_100_gross_monthly_median_df.iloc[i]['degree'])
        top_100_gmm_unique_rp_university.append(top_100_gross_monthly_median_df.iloc[i]['University'])
        top_100_gmm_unique_rp_RP.append(top_100_gross_monthly_median_df.iloc[i]['Rank Points'])
        top_100_gmm_unique_rp_stream.append(top_100_gross_monthly_median_df.iloc[i]['Stream'])
        top_100_gmm_unique_rp_gmm.append(top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median'])
        top_100_gmm_unique_rp_streamandRP.append((top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
                                                top_100_gross_monthly_median_df.iloc[i]['Stream']))
        top_100_gmm_unique_rp.append((top_100_gross_monthly_median_df.iloc[i]['degree'],
                                     top_100_gross_monthly_median_df.iloc[i]['University'],
                                   top_100_gross_monthly_median_df.iloc[i]['Stream'],
                                   top_100_gross_monthly_median_df.iloc[i]['Rank Points'],
                                   top_100_gross_monthly_median_df.iloc[i]['Gross Monthly Median']))

# %%
len(top_100_gmm_unique_rp_degree)
# Out:
# 30

# %%
top_100_gmm_unique_df=pd.DataFrame(data={'Degree':top_100_gmm_unique_rp_degree,
                                        'University':top_100_gmm_unique_rp_university,
                                        'Stream':top_100_gmm_unique_rp_stream,
                                        'Rank Points':top_100_gmm_unique_rp_RP,
                                       'Gross Monthly Median':top_100_gmm_unique_rp_gmm})

# %%
top_100_gmm_unique_df
# Out:
#                                                Degree  \
# 0                                            Medicine
# 1                                    Bachelor of Laws
# 2        Bachelor of Medicine and Bachelor of Surgery
# 3                              Business and Computing
# 4   Bachelor of Science in Computer Science in Rea...
# 5   Bachelor of Engineering (Information Systems T...
# 6                                 Information Systems
# 7                   Information Engineering and Media
# 8    Bachelor of Engineering (Electrical Engineering)
# 9   Bachelor of Engineering (Materials Science and...
# 10     Bachelor of Engineering (Computer Engineering)
# 11  Bachelor of Engineering (Engineering Product D...
# 12  Bachelor of Engineering in Systems Engineering...
# 13              Chemical and Biomolecular Engineering
# 14                              Arts (with Education)
# 15  Bachelor of Science in Computer Science and Ga...
# 16              Electrical and Electronic Engineering
# 17                              Mathematical Sciences
# 18                          Environmental Engineering
# 19                                     Bioengineering
# 20                                            History
# 21                                         Philosophy
# 22                          Physics & Applied Physics
# 23                                         Psychology
# 24                   Chemistry & Biological Chemistry
# 25                  Bachelor of Science (Real Estate)
# 26                      Bachelor of Science (Nursing)
# 27                      Sports Science and Management
# 28                  Bachelor of Environmental Studies
# 29                              Communication Studies
#
#                                        University Stream  Rank Points  \
# 0                Nanyang Technological University      S        90.00
# 1                National University of Singapore      A        85.00
# 2                National University of Singapore      S        85.00
# 3                Nanyang Technological University      A        83.75
# 4               Singapore Institute of Technology      S        83.75
# 5   Singapore University of Technology and Design      S        75.00
# 6                 Singapore Management University      S        78.75
# 7                Nanyang Technological University      S        77.50
# 8                National University of Singapore      A        67.50
# 9                National University of Singapore      S        82.50
# 10               National University of Singapore      S        72.50
# 11  Singapore University of Technology and Design      S        71.25
# 12              Singapore Institute of Technology      S        70.00
# 13               Nanyang Technological University      S        73.75
# 14               Nanyang Technological University      A        72.50
# 15              Singapore Institute of Technology      A        80.00
# 16               Nanyang Technological University      A        73.75
# 17               Nanyang Technological University      A        76.25
# 18               Nanyang Technological University      S        66.25
# 19               Nanyang Technological University      S        80.00
# 20               Nanyang Technological University      A        75.00
# 21               Nanyang Technological University      A        70.00
# 22               Nanyang Technological University      S        65.00
# 23               Nanyang Technological University      A        78.75
# 24               Nanyang Technological University      S        76.25
# 25               National University of Singapore      A        71.25
# 26               National University of Singapore      S        67.50
# 27               Nanyang Technological University      S        68.75
# 28               National University of Singapore      S        81.25
# 29               Nanyang Technological University      A        81.25
#
#     Gross Monthly Median
# 0                   5700
# 1                   5400
# 2                   5237
# 3                   4833
# 4                   4400
# 5                   4400
# 6                   4300
# 7                   4000
# 8                   4000
# 9                   4000
# 10                  4000
# 11                  4000
# 12                  3975
# 13                  3800
# 14                  3800
# 15                  3800
# 16                  3700
# 17                  3599
# 18                  3510
# 19                  3500
# 20                  3500
# 21                  3500
# 22                  3500
# 23                  3400
# 24                  3400
# 25                  3400
# 26                  3358
# 27                  3350
# 28                  3325
# 29                  3200

# %%
top_100_gmm_unique_df.sort_values(by='Rank Points',ascending=False)
# Out:
#                                                Degree  \
# 0                                            Medicine
# 2        Bachelor of Medicine and Bachelor of Surgery
# 1                                    Bachelor of Laws
# 3                              Business and Computing
# 4   Bachelor of Science in Computer Science in Rea...
# 9   Bachelor of Engineering (Materials Science and...
# 28                  Bachelor of Environmental Studies
# 29                              Communication Studies
# 19                                     Bioengineering
# 15  Bachelor of Science in Computer Science and Ga...
# 6                                 Information Systems
# 23                                         Psychology
# 7                   Information Engineering and Media
# 24                   Chemistry & Biological Chemistry
# 17                              Mathematical Sciences
# 20                                            History
# 5   Bachelor of Engineering (Information Systems T...
# 13              Chemical and Biomolecular Engineering
# 16              Electrical and Electronic Engineering
# 10     Bachelor of Engineering (Computer Engineering)
# 14                              Arts (with Education)
# 11  Bachelor of Engineering (Engineering Product D...
# 25                  Bachelor of Science (Real Estate)
# 21                                         Philosophy
# 12  Bachelor of Engineering in Systems Engineering...
# 27                      Sports Science and Management
# 26                      Bachelor of Science (Nursing)
# 8    Bachelor of Engineering (Electrical Engineering)
# 18                          Environmental Engineering
# 22                          Physics & Applied Physics
#
#                                        University Stream  Rank Points  \
# 0                Nanyang Technological University      S        90.00
# 2                National University of Singapore      S        85.00
# 1                National University of Singapore      A        85.00
# 3                Nanyang Technological University      A        83.75
# 4               Singapore Institute of Technology      S        83.75
# 9                National University of Singapore      S        82.50
# 28               National University of Singapore      S        81.25
# 29               Nanyang Technological University      A        81.25
# 19               Nanyang Technological University      S        80.00
# 15              Singapore Institute of Technology      A        80.00
# 6                 Singapore Management University      S        78.75
# 23               Nanyang Technological University      A        78.75
# 7                Nanyang Technological University      S        77.50
# 24               Nanyang Technological University      S        76.25
# 17               Nanyang Technological University      A        76.25
# 20               Nanyang Technological University      A        75.00
# 5   Singapore University of Technology and Design      S        75.00
# 13               Nanyang Technological University      S        73.75
# 16               Nanyang Technological University      A        73.75
# 10               National University of Singapore      S        72.50
# 14               Nanyang Technological University      A        72.50
# 11  Singapore University of Technology and Design      S        71.25
# 25               National University of Singapore      A        71.25
# 21               Nanyang Technological University      A        70.00
# 12              Singapore Institute of Technology      S        70.00
# 27               Nanyang Technological University      S        68.75
# 26               National University of Singapore      S        67.50
# 8                National University of Singapore      A        67.50
# 18               Nanyang Technological University      S        66.25
# 22               Nanyang Technological University      S        65.00
#
#     Gross Monthly Median
# 0                   5700
# 2                   5237
# 1                   5400
# 3                   4833
# 4                   4400
# 9                   4000
# 28                  3325
# 29                  3200
# 19                  3500
# 15                  3800
# 6                   4300
# 23                  3400
# 7                   4000
# 24                  3400
# 17                  3599
# 20                  3500
# 5                   4400
# 13                  3800
# 16                  3700
# 10                  4000
# 14                  3800
# 11                  4000
# 25                  3400
# 21                  3500
# 12                  3975
# 27                  3350
# 26                  3358
# 8                   4000
# 18                  3510
# 22                  3500

# %%
top_100_gmm_unique_df_arts=top_100_gmm_unique_df[top_100_gmm_unique_df['Stream']=='A']
top_100_gmm_unique_df_science=top_100_gmm_unique_df[top_100_gmm_unique_df['Stream']=='S']

# %%
top_100_gross_monthly_median_df_arts=top_100_gross_monthly_median_df[top_100_gross_monthly_median_df['Stream']=='A']
top_100_gross_monthly_median_df_science=top_100_gross_monthly_median_df[top_100_gross_monthly_median_df['Stream']=='S']

# %%
top_100_gross_monthly_median_df_arts
# Out:
#                                                degree  \
# 1                                    Bachelor of Laws
# 6                              Business and Computing
# 17   Bachelor of Engineering (Electrical Engineering)
# 31                              Arts (with Education)
# 33  Bachelor of Science in Computer Science and Ga...
# 37              Electrical and Electronic Engineering
# 44                              Mathematical Sciences
# 49                                            History
# 50                                         Philosophy
# 53                        Bachelor of Social Sciences
# 55                                  Bachelor of Music
# 56                                    Social Sciences
# 59                                         Psychology
# 62                  Bachelor of Science (Real Estate)
# 67                                          Sociology
# 69               Bachelor of Arts (Industrial Design)
# 71                    Bachelor of Arts in Game Design
# 72                                            Chinese
# 73                              Communication Studies
# 74               Linguistics And Multilingual Studies
# 75                                   Bachelor of Arts
# 77  Bachelor of Fine Arts in Digital Art and Anima...
# 80                                Art, Design & Media
# 81                                            English
# 84              Bachelor of Human Resource Management
#
#                                  University  Gross Monthly Median  GMM_25pct  \
# 1          National University of Singapore                  5400       4500
# 6          Nanyang Technological University                  4833       3600
# 17         National University of Singapore                  4000       3600
# 31         Nanyang Technological University                  3800       3600
# 33        Singapore Institute of Technology                  3800       3550
# 37         Nanyang Technological University                  3700       3500
# 44         Nanyang Technological University                  3599       3215
# 49         Nanyang Technological University                  3500       3200
# 50         Nanyang Technological University                  3500       3300
# 53         National University of Singapore                  3500       3212
# 55         National University of Singapore                  3500       2875
# 56          Singapore Management University                  3500       3065
# 59         Nanyang Technological University                  3400       3100
# 62         National University of Singapore                  3400       3100
# 67         Nanyang Technological University                  3300       3040
# 69         National University of Singapore                  3300       3000
# 71        Singapore Institute of Technology                  3220       3000
# 72         Nanyang Technological University                  3210       2980
# 73         Nanyang Technological University                  3200       2800
# 74         Nanyang Technological University                  3200       3000
# 75         National University of Singapore                  3200       2800
# 77        Singapore Institute of Technology                  3150       2750
# 80         Nanyang Technological University                  3000       2800
# 81         Nanyang Technological University                  3000       2565
# 84  Singapore University of Social Sciences                  3000       2800
#
#     GMM_75pct  Gross Monthly Mean  Rank Points Stream
# 1        5800                5160        85.00      A
# 6        5000                4562        83.75      A
# 17       4600                4101        67.50      A
# 31       3806                3710        72.50      A
# 33       4000                3791        80.00      A
# 37       4000                3884        73.75      A
# 44       4070                3848        76.25      A
# 49       3800                3498        75.00      A
# 50       3584                3369        70.00      A
# 53       3850                3674        76.25      A
# 55       3900                3575        75.00      A
# 56       4000                3629        76.25      A
# 59       3800                3506        78.75      A
# 62       3650                3494        71.25      A
# 67       3600                3441        75.00      A
# 69       3500                3245        73.75      A
# 71       3500                3167        75.00      A
# 72       3500                3260        71.25      A
# 73       3500                3264        81.25      A
# 74       3740                3365        71.25      A
# 75       3700                3456        76.25      A
# 77       3275                3051        75.00      A
# 80       3500                3068        71.25      A
# 81       3500                2997        71.25      A
# 84       3300                2975        75.00      A

# %%
top_100_gmm_unique_df_arts
# Out:
#                                                Degree  \
# 1                                    Bachelor of Laws
# 3                              Business and Computing
# 8    Bachelor of Engineering (Electrical Engineering)
# 14                              Arts (with Education)
# 15  Bachelor of Science in Computer Science and Ga...
# 16              Electrical and Electronic Engineering
# 17                              Mathematical Sciences
# 20                                            History
# 21                                         Philosophy
# 23                                         Psychology
# 25                  Bachelor of Science (Real Estate)
# 29                              Communication Studies
#
#                            University Stream  Rank Points  \
# 1    National University of Singapore      A        85.00
# 3    Nanyang Technological University      A        83.75
# 8    National University of Singapore      A        67.50
# 14   Nanyang Technological University      A        72.50
# 15  Singapore Institute of Technology      A        80.00
# 16   Nanyang Technological University      A        73.75
# 17   Nanyang Technological University      A        76.25
# 20   Nanyang Technological University      A        75.00
# 21   Nanyang Technological University      A        70.00
# 23   Nanyang Technological University      A        78.75
# 25   National University of Singapore      A        71.25
# 29   Nanyang Technological University      A        81.25
#
#     Gross Monthly Median
# 1                   5400
# 3                   4833
# 8                   4000
# 14                  3800
# 15                  3800
# 16                  3700
# 17                  3599
# 20                  3500
# 21                  3500
# 23                  3400
# 25                  3400
# 29                  3200

# %%
x_arts=[]
y_arts=[]
for i in range(len(top_100_gross_monthly_median_df_arts)):
    x_arts.append(top_100_gross_monthly_median_df_arts['Rank Points'].iloc[i])
    y_arts.append(top_100_gross_monthly_median_df_arts['Gross Monthly Median'].iloc[i])
    
x_arts_df=pd.DataFrame(data={'Rank Ponts':x_arts})
y_arts_df=pd.DataFrame(data={'Gross Monthly Median':y_arts})

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Model applied on sample size of 6... too small would be rly good to have distribution of A level scores

# %%
x_arts_train,x_arts_test,y_arts_train,y_arts_test=train_test_split(x_arts_df,y_arts_df,test_size=0.2)

# %%
linreg=LinearRegression()
linreg.fit(x_arts_train,y_arts_train)
# Out:
# LinearRegression()

# %%
regline_x = x_arts_train
regline_y = linreg.intercept_ + linreg.coef_ * x_arts_train
f = plt.figure(figsize=(16, 8))
plt.scatter(x_arts_train, y_arts_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
x_science=[]
y_science=[]
for i in range(len(top_100_gross_monthly_median_df_science)):
    x_science.append(top_100_gross_monthly_median_df_science['Rank Points'].iloc[i])
    y_science.append(top_100_gross_monthly_median_df_science['Gross Monthly Median'].iloc[i])
    
x_science_df=pd.DataFrame(data={'Rank Ponts':x_science})
y_science_df=pd.DataFrame(data={'Gross Monthly Median':y_science})

x_science_train,x_science_test,y_science_train,y_science_test=train_test_split(x_science_df,y_science_df,test_size=0.2)
linregsci=LinearRegression()
linregsci.fit(x_science_train,y_science_train)
regline_xsci = x_science_train
regline_ysci = linreg.intercept_ + linreg.coef_ * x_science_train
f = plt.figure(figsize=(16, 8))
plt.scatter(x_science_train, y_science_train)
plt.plot(regline_xsci, regline_ysci, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# ### From this you are able to predict your projected income based on your RP and stream of choice.

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import f1_score

# %%
ges_df_arts=graduate_employment_survey[graduate_employment_survey['Stream']=='A']
ges_df_business=graduate_employment_survey[graduate_employment_survey['Stream']=='B']
ges_df_science=graduate_employment_survey[graduate_employment_survey['Stream']=='S']
x_100_arts=[]
y_100_arts=[]
for i in range(len(ges_df_arts)):
    x_100_arts.append(ges_df_arts['Rank Points'].iloc[i])
    y_100_arts.append(ges_df_arts['gross_monthly_median'].iloc[i])

x_100_arts_df=pd.DataFrame(data={'Rank Ponts':x_100_arts})
y_100_arts_df=pd.DataFrame(data={'Gross Monthly Median':y_100_arts})


x_100_business=[]
y_100_business=[]
for i in range(len(ges_df_business)):
    x_100_business.append(ges_df_business['Rank Points'].iloc[i])
    y_100_business.append(ges_df_business['gross_monthly_median'].iloc[i])

x_100_business_df=pd.DataFrame(data={'Rank Ponts':x_100_business})
y_100_business_df=pd.DataFrame(data={'Gross Monthly Median':y_100_business})

x_100_science=[]
y_100_science=[]
for i in range(len(ges_df_science)):
    x_100_science.append(ges_df_science['Rank Points'].iloc[i])
    y_100_science.append(ges_df_science['gross_monthly_median'].iloc[i])

x_100_science_df=pd.DataFrame(data={'Rank Ponts':x_100_science})
y_100_science_df=pd.DataFrame(data={'Gross Monthly Median':y_100_science})

x_100_arts_train,x_100_arts_test,y_100_arts_train,y_100_arts_test=train_test_split(x_100_arts_df,y_100_arts_df,test_size=0.2)
x_100_science_train,x_100_science_test,y_100_science_train,y_100_science_test=train_test_split(x_100_science_df,y_100_science_df,test_size=0.2)
x_100_business_train,x_100_business_test,y_100_business_train,y_100_business_test=train_test_split(x_100_business_df,y_100_business_df,test_size=0.2)

linreg3=LinearRegression()
linreg3.fit(x_100_arts_train,y_100_arts_train)
regline_xarts100 = x_100_arts_train
regline_yarts100 = linreg3.intercept_ + linreg3.coef_ * x_100_arts_train
linreg4=LinearRegression()
linreg4.fit(x_100_science_train,y_100_science_train)
regline_xsci100 = x_100_science_train
regline_ysci100 = linreg4.intercept_ + linreg4.coef_ * x_100_science_train
linreg5=LinearRegression()
linreg5.fit(x_100_business_train,y_100_business_train)
regline_xbiz100= x_100_business_train
regline_ybiz100=linreg5.intercept_ + linreg5.coef_ * x_100_business_train
f = plt.figure(figsize=(16, 8))
plt.scatter(x_100_science_df, y_100_science_df)
plt.scatter(x_100_arts_df,y_100_arts_df,c='g')
plt.scatter(x_100_business_df,y_100_business_df,c='blue')
plt.plot(regline_xbiz100,regline_ybiz100,'g-')
plt.plot(regline_xsci100, regline_ysci100, 'r-')
plt.plot(regline_xarts100,regline_yarts100,'y-')
plt.show()

print("Goodness of Fit of Model (Arts) \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg3.score(x_100_arts_train, y_100_arts_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_arts_train, linreg3.predict(x_100_arts_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model (Arts) \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg3.score(x_100_arts_test, y_100_arts_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_arts_test, linreg3.predict(x_100_arts_test)))
print()

print("Goodness of Fit of Model (Business) \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg5.score(x_100_business_train, y_100_business_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_business_train, linreg3.predict(x_100_business_train)))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model (Business) \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg5.score(x_100_arts_test, y_100_arts_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_arts_test, linreg3.predict(x_100_arts_test)))
print()

print("Goodness of Fit of Model (Science)\tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg4.score(x_100_science_train, y_100_science_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_science_train, linreg4.predict(x_100_science_train)))

print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model (Science)\tTest Dataset")
print("Explained Variance (R^2) \t:", linreg4.score(x_100_science_test, y_100_science_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_100_science_test, linreg4.predict(x_100_science_test)))

print()
# Out:
# Goodness of Fit of Model (Arts) 	Train Dataset
# Explained Variance (R^2) 	: 0.10534458554133608
# Mean Squared Error (MSE) 	: 171951.2836970475
#
# Goodness of Fit of Model (Arts) 	Test Dataset
# Explained Variance (R^2) 	: 0.24555936105364295
# Mean Squared Error (MSE) 	: 596309.8810232006
#
# Goodness of Fit of Model (Business) 	Train Dataset
# Explained Variance (R^2) 	: 0.33164920429178335
# Mean Squared Error (MSE) 	: 166863.64408940263
#
# Goodness of Fit of Model (Business) 	Test Dataset
# Explained Variance (R^2) 	: 0.40035483674463956
# Mean Squared Error (MSE) 	: 596309.8810232006
#
# Goodness of Fit of Model (Science)	Train Dataset
# Explained Variance (R^2) 	: 0.4333329273876243
# Mean Squared Error (MSE) 	: 169753.26369740488
#
# Goodness of Fit of Model (Science)	Test Dataset
# Explained Variance (R^2) 	: -1.7869691278118682
# Mean Squared Error (MSE) 	: 517196.13117899746

# %%
def salarypref():
    user2_RP=float(input("Please enter your rank points: "))
    while (user2_RP>90):
        user2_RP=float(input("Please enter your rank points: "))    
    user2_stream=input("Please enter your preferred stream (A for Arts, B for Business, S for Science): ")
    user2_stream=user2_stream.capitalize()
    while (user2_stream not in ['A','B','S']):
        user2_stream=input("Please enter your preferred stream (A for Arts, B for Business, S for Science): ")
    user2_stream=user2_stream.capitalize()
    if user2_stream=='A':
        user_df=graduate_employment_survey[graduate_employment_survey['Stream']=='A']
    elif user2_stream=='B':
        user_df=graduate_employment_survey[graduate_employment_survey['Stream']=='B']
    else:
        user_df=graduate_employment_survey[graduate_employment_survey['Stream']=='S']
    user_df=user_df[user_df['Rank Points']<=user2_RP]
    courselist2=[]
    max_Sal2=0
    for i in range(len(user_df)):
        if (user_df.iloc[i]['gross_monthly_median']>max_Sal2):
            courselist2=[]
            max_Sal2=user_df.iloc[i]['gross_monthly_median']
            courselist2.append(user_df.iloc[i]['degree']+" at "+user_df.iloc[i]['university'])
        elif(user_df.iloc[i]['gross_monthly_median']==max_Sal2):
            courselist2.append(user_df.iloc[i]['degree']+" at "+user_df.iloc[i]['university'])
    print("Your recommended choice of courses are: ")
    for i in courselist2:
        print(i)
    print ()
    print("The corresponding salary of these courses is: ")
    print(max_Sal2)
    print()
    print("The salary you can expect to achieve based on your rank point and preferred stream is:")
    if (user2_stream=='A'):
        y=linreg3.intercept_ + linreg3.coef_*user2_RP
    elif (user2_stream=='S'):
        y=linreg4.intercept_ + linreg3.coef_*user2_RP
    else:
        y=linreg5.intercept_+linreg5.coef_*user2_RP
    print(int(y[0][0]))
    print()

# %%
def passionpref():
    import scipy.stats
    user_df=pd.DataFrame(columns=graduate_employment_survey.columns)
    listofdeg=user_passion_func()
    for i in listofdeg:
        user_df=user_df.append(graduate_employment_survey.iloc[i])
    user2_RP=float(input("Please enter your rank points: "))
    while (user2_RP>90):
        user2_RP=float(input("Please enter your rank points: "))    
    user2_sal=float(input("Please enter your ideal salary: "))
    user_df=user_df[user_df['Rank Points']<=user2_RP]
    courselist2=[]
    max_Sal2=0
    for i in range(len(user_df)):
        if (user_df.iloc[i]['gross_monthly_median']>=user2_sal):
            #if (user_df.iloc[i][''])
            courselist2.append((user_df.iloc[i]['degree'],user_df.iloc[i]['gross_mthly_25_percentile'],
                                user_df.iloc[i]['gross_mthly_75_percentile'],user_df.iloc[i]['gross_monthly_median'],
                                user_df.iloc[i]['Rank Points'],user_df.iloc[i]['gross_monthly_mean']))
    if len(courselist2)>0:
        print("\n" + str(len(courselist2)) + " course(s) match your requirements! \n")
    else:
        print("No courses match your requirements based on your rank points.")
        return
    for i in range(len(courselist2)):
        mean1=float(courselist2[i][5])
        sd1=(float(courselist2[i][2])-float(courselist2[i][1]))/1.35
        z1=(user2_sal-mean1)/sd1
        probability1=scipy.stats.norm.sf(abs(z1))
        courselist2[i]=(courselist2[i][0],courselist2[i][1],courselist2[i][2],
                        courselist2[i][3],courselist2[i][4],courselist2[i][5],100-probability1*100)
        for j in range(len(courselist2)):
            mean2=float(courselist2[j][5])
            sd2=(float(courselist2[j][2])-float(courselist2[j][1]))/1.35
            z2=(user2_sal-mean2)/sd2
            probability2=scipy.stats.norm.sf(abs(z2))            
            courselist2[j]=(courselist2[j][0],courselist2[j][1],courselist2[j][2],
                            courselist2[j][3],courselist2[j][4],courselist2[j][5],100-probability2*100)
            if courselist2[i][-1]>courselist2[j][-1]:
                temp=courselist2[i]
                courselist2[i]=courselist2[j]
                courselist2[j]=temp
    listcounter=input("Please enter the number of results you would like to view at once: ")
    while listcounter.isdigit()==False:
        listcounter=(input("Please enter the number of results you would like to view at once: "))
    listcounter=int(listcounter)
    k=(len(courselist2)/listcounter)
    if k%1!=0:
        if (k%1>0.5):
            k=round(k)
        else:
            k=round(k)+1
    k=int(k)
    for c in range(k):
        if (c!=k-1):
            print("Returning results "+str(c*listcounter+1)+" to "+str((c+1)*listcounter) +" of "+str(len(courselist2)))
            print()
        else:
            print("Returning results "+str(c*listcounter+1)+" to "+str(len(courselist2)))
            print()
        if (c+1)*listcounter<=len(courselist2):
            lowerval=(c+1)*listcounter
        else:
            lowerval=len(courselist2)
        for d in range(c*listcounter,lowerval):
            print(courselist2[d][0])
            print("Likelihood of achieving salary: ")
            if (courselist2[d][-1]>75):
                print("Highly likely, probability is: "+str(round(courselist2[d][-1]))+"%")                
            elif (courselist2[d][-1]>50):
                print ("Likely, probability is: "+str(round(courselist2[d][-1]))+"%")
            else:
                print ("Unlikely, probability is: "+str(round(courselist2[d][-1]))+"%")
            print("The gross monthly mean for this course is: "+str(courselist2[d][5]))
            print("The rank point requirement for this course is: "+str(courselist2[d][4]))
            print()
        if c==k-1:
            break;
        l=input("Enter . to stop search")
        if l=='.':
            break
        else:
            print()

# %%
a=int(input("Please enter your preference: Passion (0) or Salary (1): "))
while a not in range (0,2):
    a=a=int(input("Please enter your preference: Passion (0) or Salary (1): "))
if a==0:
    passionpref()
elif a==1:
    salarypref()
# Out:
# Please enter your preference: Passion (0) or Salary (1): 0
#
# Please enter your passion (Enter '.' to end): Computing
# Business and Computing at Nanyang Technological University
# Computer Engineering at Nanyang Technological University
# Computer Science at Nanyang Technological University
# Bachelor of Computing (Computer Science) at National University of Singapore
# Bachelor of Computing (Information Systems) at National University of Singapore
# Bachelor of Engineering (Computer Engineering) at National University of Singapore
# Bachelor of Science in Computer Science and Game Design at Singapore Institute of Technology
# Bachelor of Science in Computer Science in Real-Time Interactive Simulation at Singapore Institute of Technology
#
# Please enter your passion (Enter '.' to end): Math
# Mathematical Sciences at Nanyang Technological University
# Mathematics & Economics at Nanyang Technological University
#
# Please enter your passion (Enter '.' to end): Chinese
# Chinese at Nanyang Technological University
# Biomedical Sciences & Chinese Medicine at Nanyang Technological University
#
# Please enter your passion (Enter '.' to end): .
#
# Business and Computing at Nanyang Technological University
# Computer Engineering at Nanyang Technological University
# Computer Science at Nanyang Technological University
# Bachelor of Computing (Computer Science) at National University of Singapore
# Bachelor of Computing (Information Systems) at National University of Singapore
# Bachelor of Engineering (Computer Engineering) at National University of Singapore
# Bachelor of Science in Computer Science and Game Design at Singapore Institute of Technology
# Bachelor of Science in Computer Science in Real-Time Interactive Simulation at Singapore Institute of Technology
# Mathematical Sciences at Nanyang Technological University
# Mathematics & Economics at Nanyang Technological University
# Chinese at Nanyang Technological University
# Biomedical Sciences & Chinese Medicine at Nanyang Technological University
# Please enter your rank points: 78.75
# Please enter your ideal salary: 3450
#
# 4 course(s) match your requirements!
#
# Please enter the number of results you would like to view at once: 1
# Returning results 1 to 1 of 4
#
# Bachelor of Science in Computer Science in Real-Time Interactive Simulation
# Likelihood of achieving salary:
# Highly likely, probability is: 88%
# The gross monthly mean for this course is: 4474
# The rank point requirement for this course is: 75.0
#
# Enter . to stop searche
#
# Returning results 2 to 2 of 4
#
# Bachelor of Science in Computer Science and Game Design
# Likelihood of achieving salary:
# Highly likely, probability is: 85%
# The gross monthly mean for this course is: 3791
# The rank point requirement for this course is: 75.0
#
# Enter . to stop searchee
#
# Returning results 3 to 3 of 4
#
# Computer Engineering
# Likelihood of achieving salary:
# Highly likely, probability is: 83%
# The gross monthly mean for this course is: 4074
# The rank point requirement for this course is: 75.0
#
# Enter . to stop searchp
#
# Returning results 4 to 4
#
# Mathematical Sciences
# Likelihood of achieving salary:
# Likely, probability is: 74%
# The gross monthly mean for this course is: 3848
# The rank point requirement for this course is: 72.5

# %% [markdown]
# #

# %% [markdown]
# ##### graduate_employment_survey.columns

# %%
column1=graduate_employment_survey['gross_monthly_median']
column2=graduate_employment_survey['Rank Points']
correlation=column1.corr(column2)

# %%
print(correlation)
# Out:
# 0.46707962838707207

# %%
columns=['employment_rate_overall','employment_rate_ft_perm','basic_monthly_mean','basic_monthly_median',
         'gross_monthly_mean','gross_monthly_median','gross_mthly_25_percentile','gross_mthly_75_percentile',
         'Rank Points']

# %%
for i in columns:
    print()
    print(i)
    for j in columns:
        print("with "+j)
        correlation=graduate_employment_survey[i].corr(graduate_employment_survey[j])
        print(correlation)
# Out:
# employment_rate_overall
# with employment_rate_overall
# 1.0
# with employment_rate_ft_perm
# 0.8224259140607507
# with basic_monthly_mean
# 0.5202573050495876
# with basic_monthly_median
# 0.5047320663828959
# with gross_monthly_mean
# 0.49989002202051214
# with gross_monthly_median
# 0.4750039516398328
# with gross_mthly_25_percentile
# 0.5196274458458804
# with gross_mthly_75_percentile
# 0.42398868750601687
# with Rank Points
# 0.31294796796349245
#
# employment_rate_ft_perm
# with employment_rate_overall
# 0.8224259140607507
# with employment_rate_ft_perm
# 0.9999999999999999
# with basic_monthly_mean
# 0.5829836643509966
# with basic_monthly_median
# 0.5443359780566775
# with gross_monthly_mean
# 0.5692257555815048
# with gross_monthly_median
# 0.5332901442084732
# with gross_mthly_25_percentile
# 0.627285830945595
# with gross_mthly_75_percentile
# 0.49596961157197084
# with Rank Points
# 0.23460249788863213
#
# basic_monthly_mean
# with employment_rate_overall
# 0.5202573050495874
# with employment_rate_ft_perm
# 0.5829836643509966
# with basic_monthly_mean
# 1.0
# with basic_monthly_median
# 0.927465121031086
# with gross_monthly_mean
# 0.9839222527387098
# with gross_monthly_median
# 0.9112750303737499
# with gross_mthly_25_percentile
# 0.8546191135461382
# with gross_mthly_75_percentile
# 0.9499344781276347
# with Rank Points
# 0.4278913988286139
#
# basic_monthly_median
# with employment_rate_overall
# 0.5047320663828959
# with employment_rate_ft_perm
# 0.5443359780566775
# with basic_monthly_mean
# 0.927465121031086
# with basic_monthly_median
# 1.0
# with gross_monthly_mean
# 0.9094196501115811
# with gross_monthly_median
# 0.9698837870511147
# with gross_mthly_25_percentile
# 0.8958215649453741
# with gross_mthly_75_percentile
# 0.8885897808033109
# with Rank Points
# 0.4545543405933564
#
# gross_monthly_mean
# with employment_rate_overall
# 0.49989002202051214
# with employment_rate_ft_perm
# 0.5692257555815048
# with basic_monthly_mean
# 0.9839222527387099
# with basic_monthly_median
# 0.9094196501115811
# with gross_monthly_mean
# 1.0
# with gross_monthly_median
# 0.930424853621023
# with gross_mthly_25_percentile
# 0.885754884943306
# with gross_mthly_75_percentile
# 0.9678289394665355
# with Rank Points
# 0.43804549100730017
#
# gross_monthly_median
# with employment_rate_overall
# 0.4750039516398327
# with employment_rate_ft_perm
# 0.5332901442084732
# with basic_monthly_mean
# 0.9112750303737499
# with basic_monthly_median
# 0.9698837870511147
# with gross_monthly_mean
# 0.930424853621023
# with gross_monthly_median
# 1.0
# with gross_mthly_25_percentile
# 0.9434696845056759
# with gross_mthly_75_percentile
# 0.9215094127225643
# with Rank Points
# 0.46707962838707207
#
# gross_mthly_25_percentile
# with employment_rate_overall
# 0.5196274458458804
# with employment_rate_ft_perm
# 0.627285830945595
# with basic_monthly_mean
# 0.8546191135461382
# with basic_monthly_median
# 0.8958215649453742
# with gross_monthly_mean
# 0.8857548849433059
# with gross_monthly_median
# 0.9434696845056759
# with gross_mthly_25_percentile
# 0.9999999999999999
# with gross_mthly_75_percentile
# 0.8608077726145235
# with Rank Points
# 0.3869935519302259
#
# gross_mthly_75_percentile
# with employment_rate_overall
# 0.42398868750601687
# with employment_rate_ft_perm
# 0.4959696115719709
# with basic_monthly_mean
# 0.9499344781276347
# with basic_monthly_median
# 0.8885897808033109
# with gross_monthly_mean
# 0.9678289394665354
# with gross_monthly_median
# 0.9215094127225643
# with gross_mthly_25_percentile
# 0.8608077726145235
# with gross_mthly_75_percentile
# 0.9999999999999998
# with Rank Points
# 0.40593076295228153
#
# Rank Points
# with employment_rate_overall
# 0.31294796796349245
# with employment_rate_ft_perm
# 0.23460249788863213
# with basic_monthly_mean
# 0.4278913988286139
# with basic_monthly_median
# 0.4545543405933564
# with gross_monthly_mean
# 0.4380454910073002
# with gross_monthly_median
# 0.46707962838707207
# with gross_mthly_25_percentile
# 0.3869935519302259
# with gross_mthly_75_percentile
# 0.4059307629522816
# with Rank Points
# 1.0
